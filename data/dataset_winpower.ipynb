# %%
# Python Faker Dataset Generator
import pandas as pd
import random
from faker import Faker
from datetime import datetime, timedelta

fake = Faker()

# =========================
# CONFIGURATION
# =========================
num_rows = 5000

# =========================
# SAMPLE DATA
# =========================
customer_types = ['Dealer', 'Retail', 'Corporate', 'Distributor']
sales_zones = ['Dhaka', 
               'Chittagong', 
               'Sylhet', 
               'Rajshahi', 
               'Khulna', 
               'Barisal',
               'Rangpur',
               'Dinajpur',
               'Habigonj',
                'Mymensingh',
              'Rajbari']

payment_statuses = ['Paid', 'Partial', 'Due']
payment_methods = ['Cash', 'Bank Transfer', 'bKash', 'Nagad']
return_statuses = ['Returned', 'Not Returned']

customer_names = [
    'Rahim Enterprise',
    'Karim Battery House',
    'Bismillah Traders',
    'M/S Noor Enterprise',
    'Dhaka Battery Point',
    'Sylhet Power Solution',
    'Mayer Doa Traders',
    'Brothers Electronics',
    'Amin Battery Center',
    'New Bangla Enterprise',
    'Rasel Battery Gallery',
    'Mim Electronics',
    'Sadia Enterprise',
    'Tania Traders',
    'Sumi Battery House',
    'Nabil Enterprise',
    'Hasan & Brothers',
    'Maisha Corporation',
    'Rifat Enterprise',
    'Nusrat Electronics',
    'Green Power BD',
    'Power Tech Bangladesh',
    'M/S Fahim Traders',
    'M/S Tamanna Enterprise',
    'City Battery Center',
    'Rajdhani Electronics',
    'Khulna Battery House',
    'Cumilla Traders',
    'Noakhali Enterprise',
    'Chattogram Battery Point',
    'Barisal Electronics',
    'Rangpur Power House',
    'Rajshahi Battery Solution',
    'M/S Al Madina Traders',
    'M/S Golden Power',
    'Sakib Enterprise',
    'Tamim Battery House',
    'Prime Battery Center',
    'M/S Battery World',
    'Jannat Electronics',
    'Nahar Enterprise',
    'Nayeem Battery Store',
    'Arafat Traders',
    'M/S New Vision',
    'Digital Power BD',
    'Sonar Bangla Traders',
    'Fresh Battery House',
    'M/S Reliable Enterprise',
    'Win Battery Point',
    'Future Energy BD',
    'Anando Electronics Point',
    'Nikunjo Hevvey Enargy',
    'Sattar Power Solution',
    'Khan Solar Power Solution'
]

sales_persons = [
    'Rahim Ahmed',
    'Karim Hasan',
    'Sabbir Hossain',
    'Nayeem Islam',
    'Tanvir Rahman',
    'Jahid Hasan',
    'Khairul Hasan',
    'Shamim Ahmad',
    'Ruhul Kabir',
    'Nasir Uddin',
    'Sagor Ahmad'
]

region_managers = [
    'Rafiqul Islam',
    'Mahmud Hasan',
    'Shamim Ahmed',
    'Mujakkir Ahmad',
    'Omar Faruk',
    'Fayez Ahmad'
]

products = [
    ('BT1001', 'Lithium-Ion Battery', 'Lithium'),
    ('BT1002', 'Lead Acid Battery', 'Lead Acid'),
    ('BT1003', 'AGM Battery', 'AGM'),
    ('BT1004', 'Gel Battery', 'Gel'),
    ('BT1005', 'Solar Storage Battery', 'Solar'),
    ('BT1006', 'UPS Backup Battery', 'UPS'),
    ('BT1007', 'Deep Cycle Battery', 'Deep Cycle'),
    ('BT1008', 'Motorcycle Battery', 'Motorcycle'),
    ('BT1009', 'Automotive Battery', 'Automotive'),
    ('BT1010', 'Industrial Battery', 'Industrial'),
    ('BT1011', 'Lithium Polymer Battery', 'Lithium Polymer'),
    ('BT1012', 'Nickel Metal Hydride Battery', 'NiMH'),
    ('BT1013', 'Nickel Cadmium Battery', 'NiCd'),
    ('BT1014', 'Sealed Lead Acid Battery', 'SLA'),
    ('BT1015', 'Marine Battery', 'Marine'),
    ('BT1016', 'Forklift Battery', 'Forklift'),
    ('BT1017', 'Electric Bike Battery', 'E-Bike'),
    ('BT1018', 'Electric Scooter Battery', 'Scooter'),
    ('BT1019', 'Drone LiPo Battery', 'Drone'),
    ('BT1020', 'Laptop Battery Pack', 'Laptop'),
    ('BT1021', 'Smartphone Battery', 'Mobile'),
    ('BT1022', 'Power Bank Battery', 'Power Bank'),
    ('BT1023', 'Hearing Aid Battery', 'Medical'),
    ('BT1024', 'Medical Device Battery', 'Medical'),
    ('BT1025', 'Telecom Backup Battery', 'Telecom'),
    ('BT1026', 'Inverter Battery', 'Inverter'),
    ('BT1027', 'Hybrid Vehicle Battery', 'Hybrid'),
    ('BT1028', 'Start Stop Car Battery', 'Automotive'),
    ('BT1029', 'RC Car Battery', 'RC'),
    ('BT1030', 'Button Cell Battery', 'Button Cell'),
    ('BT1031', 'Coin Cell Battery', 'Coin Cell'),
    ('BT1032', 'AA Alkaline Battery', 'Alkaline'),
    ('BT1033', 'AAA Alkaline Battery', 'Alkaline'),
    ('BT1034', 'Rechargeable AA Battery', 'Rechargeable'),
    ('BT1035', 'Rechargeable AAA Battery', 'Rechargeable'),
    ('BT1036', 'Lithium Iron Phosphate Battery', 'LFP'),
    ('BT1037', 'Tesla 4680 Battery', 'EV'),
    ('BT1038', 'BYD Blade Battery', 'EV'),
    ('BT1039', 'CATL EV Battery', 'EV'),
    ('BT1040', 'Toyota Prius Hybrid Battery', 'Hybrid'),
    ('BT1041', 'Nissan Leaf Battery Pack', 'EV'),
    ('BT1042', 'Chevrolet Bolt EV Battery', 'EV'),
    ('BT1043', '12V Lead Acid Battery', 'Lead Acid'),
    ('BT1044', '24V Solar Battery', 'Solar'),
    ('BT1045', '48V Lithium Battery', 'Lithium'),
    ('BT1046', '18650 Lithium Cell', 'Lithium Cell'),
    ('BT1047', '21700 Lithium Cell', 'Lithium Cell'),
    ('BT1048', 'Prismatic Lithium Cell', 'Lithium Cell'),
    ('BT1049', 'Pouch Cell Battery', 'Pouch Cell'),
    ('BT1050', 'Cylindrical Cell Battery', 'Cylindrical'),
    ('BT1051', 'Graphene Battery', 'Graphene'),
    ('BT1052', 'Solid State Battery', 'Solid State'),
    ('BT1053', 'Sodium Ion Battery', 'Sodium Ion'),
    ('BT1054', 'Flow Battery', 'Flow'),
    ('BT1055', 'Vanadium Redox Battery', 'Vanadium'),
    ('BT1056', 'Carbon Zinc Battery', 'Carbon Zinc'),
    ('BT1057', 'Dry Cell Battery', 'Dry Cell'),
    ('BT1058', 'Wet Cell Battery', 'Wet Cell'),
    ('BT1059', 'Zinc Carbon Battery', 'Zinc Carbon'),
    ('BT1060', 'Silver Oxide Battery', 'Silver Oxide')
]

# =========================
# GENERATE DATA
# =========================
data = []

for i in range(num_rows):

    billing_date = fake.date_between(start_date='-1y', end_date='today')
    delivery_date = billing_date + timedelta(days=random.randint(1, 7))
    due_date = billing_date + timedelta(days=random.randint(7, 30))

    invoice_id = f'INV-{10000 + i}'
    customer_id = f'CUST-{random.randint(1000,9999)}'

    customer_name = random.choice(customer_names)
    customer_type = random.choice(customer_types)
    sales_zone = random.choice(sales_zones)

    sales_id = f'S-{random.randint(101,111)}'
    sales_person = random.choice(sales_persons)

    product_code, product_name, battery_type = random.choice(products)

    quantity = random.randint(1, 50)
    unit_price = random.randint(20, 1500)

    amount = quantity * unit_price

    discount_percent = random.choice([0, 2, 5, 10])
    discount_amount = amount * (discount_percent / 100)

    vat_amount = (amount - discount_amount) * 0.05

    sales_amount = amount - discount_amount + vat_amount

    payment_status = random.choice(payment_statuses)
    payment_method = random.choice(payment_methods)

    region_manager = random.choice(region_managers)

    return_status = random.choice(return_statuses)

    notes = fake.sentence(nb_words=6)

    data.append([
        billing_date,
        invoice_id,
        customer_id,
        customer_name,
        customer_type,
        sales_zone,
        sales_id,
        sales_person,
        product_code,
        product_name,
        battery_type,
        quantity,
        unit_price,
        amount,
        discount_percent,
        discount_amount,
        vat_amount,
        sales_amount,
        payment_status,
        payment_method,
        region_manager,
        delivery_date,
        due_date,
        return_status,
        notes
    ])

# =========================
# CREATE DATAFRAME
# =========================
columns = [
    'Billing_date',
    'Invoice_id',
    'Customer_id',
    'Customer_name',
    'Customer_type',
    'Sales_zone',
    'Sales_id',
    'Sales_person',
    'Product_code',
    'Product_name',
    'Battery_type',
    'Quantity',
    'Unit_price_pcs',
    'Amount',
    'Discount_percent',
    'Discount_amount',
    'VAT_amount',
    'Sales_amount',
    'Payment_status',
    'Payment_method',
    'Region_manager',
    'Delivery_date',
    'Due_date',
    'Return_status',
    'Notes'
]


df = pd.DataFrame(data, columns=columns)

# =========================
# EXPORT FILE
# =========================
df.to_excel('data/winpower_sales_dataset.xlsx', index=False)

print('Dataset Created Successfully!')
# print(df.head())
# Out:
# Dataset Created Successfully!

# %%
df = pd.read_excel('winpower_sales_dataset.xlsx')
df
# Out:
#      Billing_date Invoice_id Customer_id                Customer_name  \
# 0      2025-07-01  INV-10000   CUST-5017                  Watson-Hall
# 1      2026-03-14  INV-10001   CUST-8605                Taylor-Carney
# 2      2025-07-27  INV-10002   CUST-7477     Clark, Boyd and Thornton
# 3      2025-09-28  INV-10003   CUST-8100                    Jones Inc
# 4      2025-08-20  INV-10004   CUST-4500  Cunningham, Wall and Peters
# ...           ...        ...         ...                          ...
# 4995   2025-08-17  INV-14995   CUST-6164                    Munoz LLC
# 4996   2026-05-02  INV-14996   CUST-4995      Smith, Davis and Morrow
# 4997   2025-11-05  INV-14997   CUST-3638                  Johnson Inc
# 4998   2025-10-08  INV-14998   CUST-8847         Lyons, Fox and Arias
# 4999   2026-02-20  INV-14999   CUST-6968              Reilly and Sons
#
#      Customer_type  Sales_zone Sales_id   Sales_person Product_code  \
# ...

# %%
import pandas as pd
import random
from faker import Faker
from datetime import timedelta

fake = Faker()

# =========================
# CONFIG
# =========================
num_rows = 5000

# =========================
# MASTER DATA (RELATIONAL)
# =========================

customers = {
    'CUST-1001':'Rahim Enterprise',
    'CUST-1002':'Karim Battery House',
    'CUST-1003':'Bismillah Traders',
    'CUST-1004':'M/S Noor Enterprise',
    'CUST-1005':'Dhaka Battery Point',
    'CUST-1006':'Sylhet Power Solution',
    'CUST-1007':'Mayer Doa Traders',
    'CUST-1008':'Brothers Electronics',
    'CUST-1009':'Amin Battery Center',
    'CUST-1010':'New Bangla Enterprise',
    'CUST-1011':'Rasel Battery Gallery',
    'CUST-1012':'Mim Electronics',
    'CUST-1013':'Sadia Enterprise',
    'CUST-1014':'Tania Traders',
    'CUST-1015':'Sumi Battery House',
    'CUST-1016':'Nabil Enterprise',
    'CUST-1017':'Hasan & Brothers',
    'CUST-1018':'Maisha Corporation',
    'CUST-1019':'Rifat Enterprise',
    'CUST-1020':'Nusrat Electronics',
    'CUST-1021':'Green Power BD',
    'CUST-1022':'Power Tech Bangladesh',
    'CUST-1023':'M/S Fahim Traders',
    'CUST-1024':'M/S Tamanna Enterprise',
    'CUST-1025':'City Battery Center',
    'CUST-1026':'Rajdhani Electronics',
    'CUST-1027':'Khulna Battery House',
    'CUST-1028':'Cumilla Traders',
    'CUST-1029':'Noakhali Enterprise',
    'CUST-1030':'Chattogram Battery Point',
    'CUST-1031':'Barisal Electronics',
    'CUST-1032':'Rangpur Power House',
    'CUST-1033':'Rajshahi Battery Solution',
    'CUST-1034':'M/S Al Madina Traders',
    'CUST-1035':'M/S Golden Power',
    'CUST-1036':'Sakib Enterprise',
    'CUST-1037':'Tamim Battery House',
    'CUST-1038':'Prime Battery Center',
    'CUST-1039':'M/S Battery World',
    'CUST-1040':'Jannat Electronics',
    'CUST-1041':'Nahar Enterprise',
    'CUST-1042':'Nayeem Battery Store',
    'CUST-1043':'Arafat Traders',
    'CUST-1044':'M/S New Vision',
    'CUST-1045':'Digital Power BD',
    'CUST-1047':'Sonar Bangla Traders',
    'CUST-1048':'Fresh Battery House',
    'CUST-1049':'M/S Reliable Enterprise',
    'CUST-1050':'Win Battery Point',
    'CUST-1051':'Future Energy BD',
    'CUST-1052':'Anando Electronics Point',
    'CUST-1053':'Nikunjo Hevvey Enargy',
    'CUST-1054':'Sattar Power Solution',
    'CUST-1055':'Khan Solar Power Solution',
    "CUST-1056": "Noor Enterprise",
    "CUST-1057": "Amin Battery Center",
    "CUST-1058": "Dhaka Hot Power Solution",
    "CUST-1059": 'Sultan Power Solution',
    "CUST-1060": 'SunLight Battery'

}

sales_mapping = {
    "S-101": {"name": "Rahim Ahmed", "zone": "Dhaka"},
    "S-102": {"name": "Karim Hasan", "zone": "Chattogram"},
    "S-103": {"name": "Sabbir Hossain", "zone": "Sylhet"},
    "S-104": {"name": "Nayeem Islam", "zone": "Khulna"},
    "S-105": {"name": "Tanvir Rahman", "zone": "Rajshahi"},
    "S-106": {"name": "Jahid Hasan", "zone": "Barisal"},
    "S-107": {"name": "Rakibul Hasan", "zone": "Rangpur"},
    "S-108": {"name": "Khairul Hasan", "zone": "Patuyakhali"},
    "S-109": {"name": "Ruhul Amin", "zone": "Pabna"},
    "S-110": {"name": "Eyad Hossian", "zone": "Rajabari"},
    "S-111": {"name": "Alamgir Hossen", "zone": "Netrokuna"},
    "S-112": {"name": "Shahriar Joy", "zone": "Mymensingh"},
    "S-113": {"name": "Shamim Bepari", "zone": "Bogura"},
    "S-114": {"name": "Osman Faruk", "zone": "Habigonj"}
}

# =========================
# PRODUCTS (already yours)
# =========================

products = [
    ('BT1001', 'Lithium-Ion Battery', 'Lithium'),
    ('BT1002', 'Lead Acid Battery', 'Lead Acid'),
    ('BT1003', 'AGM Battery', 'AGM'),
    ('BT1004', 'Gel Battery', 'Gel'),
    ('BT1005', 'Solar Storage Battery', 'Solar'),
    ('BT1006', 'UPS Backup Battery', 'UPS'),
    ('BT1007', 'Deep Cycle Battery', 'Deep Cycle'),
    ('BT1008', 'Motorcycle Battery', 'Motorcycle'),
    ('BT1009', 'Automotive Battery', 'Automotive'),
    ('BT1010', 'Industrial Battery', 'Industrial'),
    ('BT1011', 'Lithium Polymer Battery', 'Lithium'),
    ('BT1012', 'Nickel Metal Hydride Battery', 'NiMH'),
    ('BT1013', 'Nickel Cadmium Battery', 'NiCd'),
    ('BT1014', 'Sealed Lead Acid Battery', 'Lead Acid'),
    ('BT1015', 'Marine Battery', 'Marine'),
    ('BT1016', 'Forklift Battery', 'Industrial'),
    ('BT1017', 'Electric Bike Battery', 'EV'),
    ('BT1018', 'Electric Scooter Battery', 'EV'),
    ('BT1019', 'Drone LiPo Battery', 'Lithium'),
    ('BT1020', 'Laptop Battery Pack', 'Lithium'),
    ('BT1021', 'Smartphone Battery', 'Lithium'),
    ('BT1022', 'Power Bank Battery', 'Lithium'),
    ('BT1023', 'Hearing Aid Battery', 'Medical'),
    ('BT1024', 'Medical Device Battery', 'Medical'),
    ('BT1025', 'Telecom Backup Battery', 'UPS'),
    ('BT1026', 'Inverter Battery', 'Lead Acid'),
    ('BT1027', 'Hybrid Vehicle Battery', 'EV'),
    ('BT1028', 'Start Stop Car Battery', 'Automotive'),
    ('BT1030', 'Button Cell Battery', 'Alkaline'),
    ('BT1031', 'Coin Cell Battery', 'Alkaline')
]

# =========================
# PRICING MAP
# =========================

price_map = {
    "Lithium": (800, 2500),
    "Lead Acid": (400, 1500),
    "AGM": (500, 1800),
    "Gel": (600, 2000),
    "Solar": (1200, 3500),
    "UPS": (500, 2000),
    "Industrial": (1500, 5000),
    "EV": (2000, 8000),
    "Automotive": (600, 2000),
    "NiMH": (100, 500),
    "NiCd": (80, 400),
    "Medical": (50, 300),
    "Alkaline": (20, 200),
    "Marine": (700, 2500),
    "Deep Cycle": (800, 3000),
    "Motorcycle": (300, 1200)
}

# =========================
# ENUMS
# =========================

customer_types = ['Dealer', 'Retail', 'Corporate', 'Distributor']
payment_statuses = ['Paid', 'Partial', 'Due']
payment_methods = ['Cash', 'Bank Transfer', 'bKash', 'Nagad']
return_statuses = ['Returned', 'Not Returned']

# =========================
# GENERATE DATA
# =========================

data = []

for i in range(num_rows):

    billing_date = fake.date_between(start_date='-1y', end_date='today')
    delivery_date = billing_date + timedelta(days=random.randint(1, 5))
    due_date = billing_date + timedelta(days=random.randint(7, 30))

    invoice_id = f'INV-{10000 + i}'

    # CUSTOMER (RELATIONAL)
    customer_id = random.choice(list(customers.keys()))
    customer_name = customers[customer_id]

    customer_type = random.choice(customer_types)

    # SALES (RELATIONAL)
    sales_id = random.choice(list(sales_mapping.keys()))
    sales_person = sales_mapping[sales_id]["name"]
    sales_zone = sales_mapping[sales_id]["zone"]

    # PRODUCT
    product_code, product_name, battery_type = random.choice(products)

    # PRICING (SMART)
    low, high = price_map.get(battery_type, (1000, 5000))
    unit_price = random.randint(low, high)

    quantity = random.randint(1, 30)

    amount = quantity * unit_price

    # DISCOUNT LOGIC
    discount_percent = random.choices([0, 2, 5, 10], weights=[50, 20, 20, 10])[0]
    discount_amount = amount * (discount_percent / 100)

    vat_amount = (amount - discount_amount) * 0.05
    sales_amount = amount - discount_amount + vat_amount

    # PAYMENT LOGIC
    payment_status = random.choices(
        payment_statuses,
        weights=[0.6, 0.25, 0.15]
    )[0]

    payment_method = random.choice(payment_methods)

    region_manager = random.choice([
        "Rafiqul Islam",
        "Mahmud Hasan",
        "Shamim Ahmed",
        "Omar Faruk",
        "Mynuddin Hasan",
        "Yousuf Mazumder Anik",
        "Nasir Uddin Ahmad",
        "Hasanuzzaman Helal"
    ])

    return_status = random.choices(return_statuses, weights=[0.1, 0.9])[0]

    notes = fake.sentence(nb_words=6)

    data.append([
        billing_date,
        invoice_id,
        customer_id,
        customer_name,
        customer_type,
        sales_zone,
        sales_id,
        sales_person,
        product_code,
        product_name,
        battery_type,
        quantity,
        unit_price,
        amount,
        discount_percent,
        discount_amount,
        vat_amount,
        sales_amount,
        payment_status,
        payment_method,
        region_manager,
        delivery_date,
        due_date,
        return_status,
        notes
    ])

# =========================
# DATAFRAME
# =========================

columns = [
    'Billing_date',
    'Invoice_id',
    'Customer_id',
    'Customer_name',
    'Customer_type',
    'Sales_zone',
    'Sales_id',
    'Sales_person',
    'Product_code',
    'Product_name',
    'Battery_type',
    'Quantity',
    'Unit_price_pcs',
    'Amount',
    'Discount_percent',
    'Discount_amount',
    'VAT_amount',
    'Sales_amount',
    'Payment_status',
    'Payment_method',
    'Region_manager',
    'Delivery_date',
    'Due_date',
    'Return_status',
    'Notes'
]

df = pd.DataFrame(data, columns=columns)

# =========================
# EXPORT
# =========================

df.to_excel("data/winpower_sales_dataset_enhanced.xlsx", index=False)

print("Dataset Generated Successfully 🚀")
#print(df.head())
# Out:
# Dataset Generated Successfully 🚀

# %%
df = pd.read_excel("winpower_sales_dataset_enhanced.xlsx")
df
# Out:
#      Billing_date Invoice_id Customer_id         Customer_name Customer_type  \
# 0      2025-12-27  INV-10000   CUST-1002   Karim Battery House        Retail
# 1      2026-03-16  INV-10001   CUST-1013      Sadia Enterprise   Distributor
# 2      2025-10-04  INV-10002   CUST-1032   Rangpur Power House        Dealer
# 3      2025-11-17  INV-10003   CUST-1017      Hasan & Brothers        Dealer
# 4      2026-04-30  INV-10004   CUST-1005   Dhaka Battery Point   Distributor
# ...           ...        ...         ...                   ...           ...
# 4995   2025-08-02  INV-14995   CUST-1041      Nahar Enterprise        Dealer
# 4996   2025-07-20  INV-14996   CUST-1038  Prime Battery Center   Distributor
# 4997   2026-01-13  INV-14997   CUST-1031   Barisal Electronics        Retail
# 4998   2025-07-23  INV-14998   CUST-1013      Sadia Enterprise   Distributor
# 4999   2025-06-23  INV-14999   CUST-1015    Sumi Battery House        Retail
#
# ...

# %%
df.describe()
# Out:
#                      Billing_date     Quantity  Unit_price_pcs         Amount  \
# count                        5000  5000.000000     5000.000000    5000.000000
# mean   2025-11-11 18:02:35.520000    15.286800     1633.297600   25355.347400
# min           2025-05-14 00:00:00     1.000000       20.000000      54.000000
# 25%           2025-08-10 00:00:00     8.000000      641.000000    4740.000000
# 50%           2025-11-09 00:00:00    15.000000     1279.000000   15520.500000
# 75%           2026-02-15 00:00:00    23.000000     2029.000000   33023.250000
# max           2026-05-14 00:00:00    30.000000     7990.000000  239610.000000
# std                           NaN     8.612536     1543.447189   31353.151754
#
#        Discount_percent  Discount_amount    VAT_amount   Sales_amount  \
# count        5000.00000      5000.000000   5000.000000    5000.000000
# mean            2.39040       600.074496   1237.763645   25993.036549
# ...

# %%
df.isnull()
# Out:
#       Billing_date  Invoice_id  Customer_id  Customer_name  Customer_type  \
# 0            False       False        False          False          False
# 1            False       False        False          False          False
# 2            False       False        False          False          False
# 3            False       False        False          False          False
# 4            False       False        False          False          False
# ...            ...         ...          ...            ...            ...
# 4995         False       False        False          False          False
# 4996         False       False        False          False          False
# 4997         False       False        False          False          False
# 4998         False       False        False          False          False
# 4999         False       False        False          False          False
#
#       Sales_zone  Sales_id  Sales_person  Product_code  Product_name  ...  \
# ...
